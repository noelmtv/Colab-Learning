# %% [markdown]
# <a href="https://colab.research.google.com/github/noelmtv/Colab-Learning/blob/main/yFinance_Downloader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import libraries#
import yfinance as yf
import pandas as pd
from datetime import datetime, timedelta
import numpy as np
from scipy.optimize import minimize
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#define the list of tickers#
tickers = [
"^GSPC","^J203.JO","^AXJO","000001.SS"
]

# %%
#SET THE END DATE TO TODAY#
end_date = datetime.today()

# %%
#Set start date#
start_date = end_date - timedelta(days=10*365)
print(start_date)
# Out:
# 2015-12-08 05:05:33.234097

# %%
#download adjusted close prices#
#This is done because you dont want to underweight a stock that pays out dividends#
adj_close_df = pd.DataFrame()
print(adj_close_df.columns)
# Out:
# RangeIndex(start=0, stop=0, step=1)

# %%
# Download the prices for each ticker#
#yFinance has by default adjusted Open/High/Low/Close, hence no need to specify 'Adj Close'
for ticker in tickers:
    data = yf.download(ticker, start=start_date, end=end_date)
    adj_close_df[ticker] = data["Close"]
# Out:
# /tmp/ipython-input-1957566553.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-1957566553.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-1957566553.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-1957566553.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed

# %%
# Store the output to your google drive
adj_close_df.to_csv('/content/drive/My Drive/Ticker Download.csv', index=False)
print(adj_close_df)
# Out:
#                   ^GSPC       ^J203.JO        ^AXJO    000001.SS
# Date
# 2015-12-08  2063.590088   49083.800781  5108.600098  3470.070068
# 2015-12-09  2047.619995   49523.558594  5080.500000  3472.438965
# 2015-12-10  2052.229980   48984.531250  5037.700195  3455.495117
# 2015-12-11  2012.369995   48067.531250  5029.500000  3434.581055
# 2015-12-14  2021.939941   48081.710938  4928.600098  3520.667969
# ...                 ...            ...          ...          ...
# 2025-11-28  6849.089844  110958.500000  8614.099609  3888.595947
# 2025-12-01  6812.629883  111947.898438  8565.200195  3914.006104
# 2025-12-02  6829.370117  110836.898438  8579.700195  3897.711914
# 2025-12-03  6849.720215  111332.703125  8595.200195  3878.000000
# 2025-12-04  6857.120117  110924.703125  8618.400391  3875.792969
#
# [2513 rows x 4 columns]

# %% [markdown]
# # List of Indices
#
# ## North America
#
# | Index                              | Ticker (Yahoo Finance)|
# | ---------------------------------- | ----------------------|
# | S&P 500 (USA)                      | **^GSPC**    |
# | Dow Jones Industrial Average (USA) | **^DJI**     |
# | NASDAQ Composite (USA)             | **^IXIC**    |
# | NYSE Composite (USA)               | **^NYA**     |
# | S&P/TSX Composite Index (Canada)   | **^GSPTSE**  |
#
#
# ## South America
#
# | Index               | Ticker (Yahoo Finance)|
# | ------------------- | ----------------------|
# | IBOVESPA (Brazil)   |       **^BVSP**       |
# | IPC México (Mexico) |       **^MXX**        |
# | MERVAL (Argentina)  |       **^MERV**       |
# | IPSA (Chile)        |       **^IPSA**       |
#
# ## Europe
# | Index                            | Ticker (Yahoo Finance)|
# | -------------------------------- | ----------------------|
# | FTSE 100 (UK)                    | **^FTSE**             |
# | DAX (Germany)                    | **^GDAXI**            |
# | CAC 40 (France)                  | **^FCHI**             |
# | IBEX 35 (Spain)                  | **^IBEX**             |
# | AEX (Netherlands)                | **^AEX**              |
# | BEL 20 (Belgium)                 | **^BEL-20**           |
# | OMX Copenhagen 20 (Denmark)      | **^OMXC20**           |
# | FTSE MIB (Italy)                 | **^FTSEMIB.MI**       |
# | Swiss Market Index (Switzerland) | **^SMI**              |
# | ATX (Austria)                    | **^ATX**              |
#
# ## Asia
#
# | Index                               | Ticker (Yahoo Finance)|
# | ----------------------------------- | --------------------- |
# | Nikkei 225 (Japan)                  | **^N225**    |
# | Hang Seng Index (Hong Kong)         | **^HSI**     |
# | SSE Composite Index (China)         | **000001.SS**|
# | S&P BSE SENSEX (India)              | **^BSESN**   |
# | KOSPI Composite Index (South Korea) | **^KS11**    |
# | Jakarta Composite Index (Indonesia) | **^JKSE**    |
# | FTSE Bursa Malaysia KLCI (Malaysia) | **^KLSE**    |
# | Straits Times Index (Singapore)     | **^STI**     |
#
#
# ## Oceania
#
# | Index                      | Ticker (Yahoo Finance) |
# | -------------------------- | -----------------------|
# | S&P/ASX 200 (Australia)    | **^AXJO** |
# | All Ordinaries (Australia) | **^AORD** |
# | S&P/NZX 50 (New Zealand).  | **^NZ50** |
#
#
#
# ## Africa
#
# | Index                         | Ticker (Yahoo Finance) |
# | ----------------------------- | -----------------------|
# | All Share Index (South Africa)|      **^J203.JO**      |
# | Top 40 Index (South Africa)   |      **^J200.JO**      |
