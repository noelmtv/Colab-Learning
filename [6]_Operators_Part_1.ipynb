# %% [markdown]
# <a href="https://colab.research.google.com/github/noelmtv/Colab-Learning/blob/Pyhon-for-Data-Analytics/%5B6%5D_Operators_Part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2 + 3.0
# Out:
# 5.0

# %%
"Whats " + "up " "gang."
# Out:
# 'Whats up gang.'

# %%
3.0 - 1
# Out:
# 2.0

# %%
"Whats Up? " * 10
# Out:
# 'Whats Up? Whats Up? Whats Up? Whats Up? Whats Up? Whats Up? Whats Up? Whats Up? Whats Up? Whats Up? '

# %%
"Whats up" - "up"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-abca31bc3937> in <cell line: 1>()
# ----> 1 "Whats up" - "up"
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
help(int)
# Out:
# Help on class int in module builtins:
#
# class int(object)
#  |  int([x]) -> integer
#  |  int(x, base=10) -> integer
#  |
#  |  Convert a number or string to an integer, or return 0 if no arguments
#  |  are given.  If x is a number, return x.__int__().  For floating point
#  |  numbers, this truncates towards zero.
#  |
#  |  If x is not a number or if base is given, then x must be a string,
#  |  bytes, or bytearray instance representing an integer literal in the
#  |  given base.  The literal can be preceded by '+' or '-' and be surrounded
#  |  by whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.
#  |  Base 0 means to interpret the base from the string as an integer literal.
#  |  >>> int('0b100', base=0)
#  |  4
#  |
#  |  Built-in subclasses:
#  |      bool
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __and__(self, value, /)
# ...

# %%
# |  __sub__(self, value, /)
# |      Return self-value.


four = 4
four.__sub__(2)
# Out:
# 2

# %%
4 - 2
# Out:
# 2

# %%
5 / 2
# Out:
# 2.5

# %%
5 // 2

# floor division to get int
# Out:
# 2

# %%
5 % 2

# This is modulus operations
# Out:
# 1

# %% [markdown]
# # Order of Operations
#
#
#
# 1.   Parentheses
# 2.   Exponents
# 3.   Multiplication and Division
# 4.   Addition and Subtraction

# %%
# "_" in a number is ignored by the interpreter

min_salary = 20_000
max_salary = 50_000

avg_salary = (min_salary + max_salary) / 2

print(avg_salary)
print(min_salary)
print(max_salary)
# Out:
# 35000.0
# 20000
# 50000

# %% [markdown]
# # Assigning Operators
#
#
#
#
# ![image.png](data:image/png;base64,...)

# %%
applicant_1 = "Kelly"
applicant_2 = "Noel"

# %%
temp_var = applicant_1

# %%
applicant_1 = applicant_2
applicant_2 = temp_var

# %%
print(f"{applicant_1} is the first applicant, whilst {applicant_2} was the second.")
# Out:
# Noel is the first applicant, whilst Kelly was the second.

# %%
applicant_1 = "Kelly"
applicant_2 = "Noel"

applicant_1, applicant_2
# Out:
# ('Kelly', 'Noel')

# %%
applicant_1, applicant_2 = applicant_2, applicant_1


applicant_1, applicant_2

# you can only do this in python
# Out:
# ('Noel', 'Kelly')

# %% [markdown]
# ### Add and assign

# %%
x = 1

# %%
x = x +1

# %%
x
# Out:
# 2

# %%
x = 1
x +=1

# %%
x
# Out:
# 2

# %%
x *=2

# %%
x
# Out:
# 4

# %% [markdown]
# # Comprison Operators
#
# ![image.png](data:image/png;base64,...)

# %%
salary_Kelly = 60_000
salary_Noel = 40_000

# %%
salary_Kelly == salary_Noel
# Out:
# False

# %%
1 == 1
# Out:
# True

# %%
1 = 1
# Out:
#   File "<ipython-input-33-ecdac3dcabfd>", line 1
#     1 = 1
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
if(salary_Kelly > salary_Noel):
    print("Kelly's salary is greater than Noel's")
# Out:
# Kelly's salary is greater than Noel's
